# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('./tabula-planningguide.csv', error_bad_lines=False)

# %%
df
# Out:
#       Unnamed: 0    Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 0            Jan           Feb           Mar           Apr
# 1          Basil  Asian greens  Asian greens         Asian
# 2          Beans         Basil     Coriander       greens#
# 3      Beetroots     Beetroots          Kale    Broadbeans
# 4       Broccoli      Broccoli         Leeks     Coriander
# 5            NaN           NaN           NaN           NaN
# 6        Brussel       Brussel     Lettuce &        Garlic
# 7        sprouts       sprouts  salad greens       Onions#
# 8            NaN           NaN           NaN           NaN
# 9      Cabbages#     Cabbages#      Parsnips      Radishes
# 10       Carrots       Carrots      Radishes     Snow peas
# 11  Cauliflower#  Cauliflower#    Silverbeet       Spinach
# 12        Celery        Celery       Spinach        Spring
# 13     Coriander     Coriander        Spring        onions
# 14          Kale          Kale        onions           NaN
# ...

# %%
df.columns = df.iloc[0]

# %%
df.head()
# Out:
# 0        Jan           Feb           Mar         Apr  \
# 0        Jan           Feb           Mar         Apr
# 1      Basil  Asian greens  Asian greens       Asian
# 2      Beans         Basil     Coriander     greens#
# 3  Beetroots     Beetroots          Kale  Broadbeans
# 4   Broccoli      Broccoli         Leeks   Coriander
#
# 0                            May Jun Jul Aug           Sep           Oct  \
# 0                            May Jun Jul Aug           Sep           Oct
# 1             Asian Asian Soil is Broadbeans  Asian greens  Asian greens
# 2   greens#  greens# generally too Jerusalem     Beetroots        Basil*
# 3  Broadbeans Broadbeans cold for artichokes      Broccoli     Beetroots
# 4            Garlic Jerusalem sowing Onions#     Coriander      Broccoli
#
# 0           Nov           Dec
# 0           Nov           Dec
# 1  Asian greens  Asian greens
# 2         Basil         Basil
# 3         Beans         Beans
# 4     Beetroots     Beetroots

# %%
df[['May', 'Jun', 'Jul', 'Aug']] = df['May Jun Jul Aug'].str.split(' ', 3, expand=True)

# %%
df.drop('May Jun Jul Aug', axis=1, inplace=True)

# %%
df1 = df.iloc[1:29]

# %%
df1
# Out:
# 0            Jan           Feb           Mar         Apr           Sep  \
# 2          Beans         Basil     Coriander     greens#     Beetroots
# 3      Beetroots     Beetroots          Kale  Broadbeans      Broccoli
# 4       Broccoli      Broccoli         Leeks   Coriander     Coriander
# 5            NaN           NaN           NaN         NaN           NaN
# 6        Brussel       Brussel     Lettuce &      Garlic     Cabbages#
# 7        sprouts       sprouts  salad greens     Onions#       Carrots
# 8            NaN           NaN           NaN         NaN           NaN
# 9      Cabbages#     Cabbages#      Parsnips    Radishes  Cauliflower#
# 10       Carrots       Carrots      Radishes   Snow peas     Jerusalem
# 11  Cauliflower#  Cauliflower#    Silverbeet     Spinach    artichokes
# 12        Celery        Celery       Spinach      Spring          Kale
# 13     Coriander     Coriander        Spring      onions         Leeks
# ...

# %%
df1=df1.replace('\*','',regex=True)

# %%
df1
# Out:
# 0            Jan           Feb           Mar         Apr           Sep  \
# 2          Beans         Basil     Coriander     greens#     Beetroots
# 3      Beetroots     Beetroots          Kale  Broadbeans      Broccoli
# 4       Broccoli      Broccoli         Leeks   Coriander     Coriander
# 5            nan           nan           nan         nan           nan
# 6        Brussel       Brussel     Lettuce &      Garlic     Cabbages#
# 7        sprouts       sprouts  salad greens     Onions#       Carrots
# 8            nan           nan           nan         nan           nan
# 9      Cabbages#     Cabbages#      Parsnips    Radishes  Cauliflower#
# 10       Carrots       Carrots      Radishes   Snow peas     Jerusalem
# 11  Cauliflower#  Cauliflower#    Silverbeet     Spinach    artichokes
# 12        Celery        Celery       Spinach      Spring          Kale
# 13     Coriander     Coriander        Spring      onions         Leeks
# ...

# %%
jan = list(df1['Jan'].unique())

# %%
feb = list(df1['Feb'].unique())

# %%
mar = list(df['Mar'].unique())

# %%
apr = list(df1['Apr'].unique())

# %%
may = list(df1['May'].unique())

# %%
jun = list(df1['Jun'].unique())

# %%
jul = list(df1['Jul'].unique())

# %%
aug = list(df1['Aug'].unique())

# %%
sep = list(df1['Sep'].unique())

# %%
octo = list(df1['Oct'].unique())

# %%
nov = list(df1['Nov'].unique())

# %%
dec = list(df1['Dec'].unique())

# %%
final = []
final = jan + feb + mar +apr + may + jun + jul + aug + sep + octo + nov + dec

# %%
final = [x for x in final if str(x) != 'nan']

# %%
removetable = str.maketrans('', '', '@*#%&')
out_list = [s.translate(removetable) for s in final]

# %%
out_list = list(filter(None, out_list))

# %%
out_list = sorted(out_list)

# %%
out_list
# Out:
# array(['Asian greens', 'Basil', 'Beans', 'Beetroots', 'Broadbeans',
#        'Broccoli', 'Brussel', 'Cabbages', 'Capsicums', 'Carrots',
#        'Cauliflower', 'Celery', 'Coriander', 'Cucumbers', 'Eggplants',
#        'Fennel', 'Garlic', 'Jerusalem', 'Kale', 'Leeks', 'Lettuce ',
#        'Mar', 'Melons', 'None', 'Onions', 'Parsnips', 'Peas', 'Potatoes',
#        'Pumpkins', 'Radishes', 'Silverbeet', 'Snow', 'Snow peas',
#        'Spinach', 'Spring', 'Sprouts', 'Sweetcorn', 'Tomatoes', 'Turnips',
#        'Zucchini', 'artichokes', 'cold', 'for artichokes',
#        'generally too Jerusalem', 'greens', 'onions', 'peas',
#        'salad greens', 'seeds)', 'sowing', 'sprouts'], dtype='<U23')

# %%
out_list = np.unique(out_list)

# %%
df2 = pd.DataFrame()

# %%
df2 = df2.assign(Plant = out_list)

# %%
x = df1.columns

# %%
for i in x:
    df2[i] = np.nan

# %%
df2.head()
# Out:
#           Plant  Jan  Feb  Mar  Apr  Sep  Oct  Nov  Dec  May  Jun  Jul  Aug
# 0  Asian greens  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1         Basil  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2         Beans  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3     Beetroots  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    Broadbeans  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
for i in df2.Plant:
    if i in df1.column:
        df2.iloc[0] = 1

# %%
df2.dropna(how='any')

# %%
df2.to_csv('iteration2.csv', sep=',', encoding='utf-8')
